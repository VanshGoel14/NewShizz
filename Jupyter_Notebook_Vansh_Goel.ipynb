# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # __My Jupyter Notebook for IBM Studio Watson__

# %% [markdown]
# ## __Vansh Goel__
# ### Data Scientist

# %% [markdown]
# _I am interested in data science because I can work remotely and it pays well._

# %% [markdown]
# The below code will return the value of (x) when i execute the print command.

# %%
x=2+5
print(x)
# Out:
# 7

# %% [markdown]
# - Coding Languages
#     - Python
#     - C++

# %% [markdown]
# 1. Monday
# 2. Tuesday
# 3. Wednesday
# 4. Thursday
# 5. Friday
# 6. Saturday
# 7. Sunday
